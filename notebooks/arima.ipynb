# %%
# setup
import statsmodels as sm
import pandas as pd
from pathlib import Path

# %%
# pull in data sets
DATA_DIR = Path.cwd().parent / "data/live"
path = DATA_DIR / "00_full_dataset.csv"
data = pd.read_csv(path)
data.head(10)
# Out:
#        Period Geo Sector Name Sub-Sector Name  \
# 0  2019-01-01  AK         ALL             ALL
# 1  2019-02-01  AK         ALL             ALL
# 2  2019-03-01  AK         ALL             ALL
# 3  2019-04-01  AK         ALL             ALL
# 4  2019-05-01  AK         ALL             ALL
# 5  2019-06-01  AK         ALL             ALL
# 6  2019-07-01  AK         ALL             ALL
# 7  2019-08-01  AK         ALL             ALL
# 8  2019-09-01  AK         ALL             ALL
# 9  2019-10-01  AK         ALL             ALL
#
#    Real Sales Index - SA_normalized  Transactional Index - SA_normalized  \
# 0                          0.259101                             0.264438
# 1                          0.254159                             0.259978
# 2                          0.257680                             0.264121
# 3                          0.257422                             0.263229
# 4                          0.263010                             0.265675
# ...

# %%
personal_consumption_cols = [col for col in data.columns if 'PersonalConsumptionExpenditure' in col]
print(personal_consumption_cols)
# Out:
# ['PersonalConsumptionExpenditures_normalized', 'PersonalConsumptionExpenditures_normalized_lag1', 'PersonalConsumptionExpenditures_normalized_lag3', 'PersonalConsumptionExpenditures_normalized_lag6', 'PersonalConsumptionExpenditures_normalized_MA3', 'PersonalConsumptionExpenditures_normalized_MA6', 'PersonalConsumptionExpenditures_normalized_MA12', 'PersonalConsumptionExpenditures_normalized_MoM_normalized', 'PersonalConsumptionExpenditures_normalized_YoY_normalized']
